# %% [markdown]
# ### Arrays

# %% [markdown]
# ####  Difference between arrays and lists is that every array element should be of the same data type

# %%
import numpy as np

# %%
a = np.array([[0,1,2,3], [4,5,6,7]])
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
#NumPy n-dimensional array = ndarray and it is always homogenous.
#array() - returns a data structure in the Numpy array format

# %%
a.shape
# Out:
# (2, 4)

# %%
a[1,3]
# Out:
# 7

# %%
a[1,2] = 8
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 8, 7]])

# %%
a[0]
# Out:
# array([0, 1, 2, 3])

# %%
a[1]
# Out:
# array([4, 5, 8, 7])

# %%
#A vector is an object that has both magnitude and direction

# %%
#1D array = vector
b = np.array([3,5])
b
# Out:
# array([3, 5])

# %%
#2D array = matrix

# %% [markdown]
# ### Generating Random Numbers

# %%
import random

# %%
prob = random.random()  #generates a random float in the range [0,1)
print(prob)
# Out:
# 0.11589554594059948

# %%
number = random.randint(1,6)  #randomizes over a provided interval and delivers an integer value
number
# Out:
# 6

# %%
import numpy as np

# %%
np.random.randint(1,6, (4,6))
# Out:
# array([[5, 5, 1, 2, 5, 5],
#        [1, 1, 1, 3, 3, 2],
#        [5, 4, 5, 4, 5, 3],
#        [3, 5, 1, 3, 2, 4]])

# %% [markdown]
# ### Importing and Organizing Your Data - Part 1

# %%
import numpy as np
import pandas as pd

# %%
# pd.Series() - single column data
ser = pd.Series(np.random.random(5), name = "Column 01")

# %%
ser
# Out:
# 0    0.517758
# 1    0.035610
# 2    0.525629
# 3    0.290975
# 4    0.125898
# Name: Column 01, dtype: float64

# %%
ser[2]
# Out:
# 0.5256292833424319

# %%
# pd.DataFrame() - several columns

# %%
from pandas_datareader import data as wb  #wb - web
#pandas_datareader is used to import data from web sources

# %%
PG = wb.DataReader('PG', data_source = 'yahoo', start = '1995-1-1')
#PG - Procter&Gamble, data_source - web server to extract data from, start - from start data till latest date 
#PG is a tikcer - every company has a symbol or code that it uses on stock exchage
#eg. Procter&Gamble - PG, Apple - AAPL, microsoft - 'MSFT'
#data - yyyy-m-d


#Data for saturdays, sundays and national holidays won't be quoted as the stock market is not open on those days i.e. trading days only

# %%
PG
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 1995-01-03   15.625000   15.437500   15.468750   15.593750  3318400.0
# 1995-01-04   15.656250   15.312500   15.531250   15.468750  2218800.0
# 1995-01-05   15.437500   15.218750   15.375000   15.250000  2319600.0
# 1995-01-06   15.406250   15.156250   15.156250   15.281250  3438000.0
# 1995-01-09   15.406250   15.187500   15.343750   15.218750  1795200.0
# ...                ...         ...         ...         ...        ...
# 2021-08-11  143.240005  142.470001  142.740005  142.619995  4205000.0
# 2021-08-12  143.149994  142.350006  143.149994  142.949997  4956100.0
# 2021-08-13  143.990005  142.690002  142.949997  143.639999  4888300.0
# 2021-08-16  144.690002  143.380005  143.669998  144.639999  6040800.0
# 2021-08-17  145.600006  143.889999  144.399994  144.880005  7577000.0
#
#              Adj Close
# Date
# 1995-01-03    8.063840
# 1995-01-04    7.999201
# 1995-01-05    7.886079
# ...

# %%
PG.info() 
#datatype
#no.of entries, start date, end date (timesoan)
#no.of columns
#number of data points, for each column, here, no missing data and data types (Volume - int, rest - float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6704 entries, 1995-01-03 to 2021-08-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       6704 non-null   float64
#  1   Low        6704 non-null   float64
#  2   Open       6704 non-null   float64
#  3   Close      6704 non-null   float64
#  4   Volume     6704 non-null   float64
#  5   Adj Close  6704 non-null   float64
# dtypes: float64(6)
# memory usage: 366.6 KB

# %%
PG.head() #first five rows
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.063840
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   7.999201
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.886079
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.902242
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.869921

# %%
PG.tail() #last five rows
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2021-08-11  143.240005  142.470001  142.740005  142.619995  4205000.0
# 2021-08-12  143.149994  142.350006  143.149994  142.949997  4956100.0
# 2021-08-13  143.990005  142.690002  142.949997  143.639999  4888300.0
# 2021-08-16  144.690002  143.380005  143.669998  144.639999  6040800.0
# 2021-08-17  145.600006  143.889999  144.399994  144.880005  7577000.0
#
#              Adj Close
# Date
# 2021-08-11  142.619995
# 2021-08-12  142.949997
# 2021-08-13  143.639999
# 2021-08-16  144.639999
# 2021-08-17  144.880005

# %%
PG.head(20) #top 20 rows
# Out:
#                 High       Low      Open     Close     Volume  Adj Close
# Date
# 1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.063840
# 1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   7.999201
# 1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.886079
# 1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.902242
# 1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.869921
# 1995-01-10  15.43750  15.18750  15.28125  15.40625  4364000.0   7.966884
# 1995-01-11  15.59375  15.37500  15.59375  15.37500  3738400.0   7.950720
# 1995-01-12  15.53125  15.31250  15.37500  15.53125  3307600.0   8.031521
# 1995-01-13  15.84375  15.53125  15.59375  15.62500  3992800.0   8.125779
# 1995-01-16  15.96875  15.75000  15.90625  15.75000  3677200.0   8.190788
# 1995-01-17  15.81250  15.65625  15.71875  15.81250  2437600.0   8.223289
# 1995-01-18  15.75000  15.43750  15.68750  15.46875  3535200.0   8.044519
# ...

# %%
PG.tail(20) #last 20 rows
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-07-21  140.199997  138.990005  139.949997  139.199997   6954700.0
# 2021-07-22  138.330002  136.710007  137.289993  137.800003   6013800.0
# 2021-07-23  139.979996  137.080002  137.479996  139.789993   7906000.0
# 2021-07-26  140.820007  139.220001  139.619995  140.279999   5925800.0
# 2021-07-27  141.619995  140.000000  140.149994  140.850006   7075400.0
# 2021-07-28  140.669998  138.710007  140.669998  138.759995   8520000.0
# 2021-07-29  140.179993  138.729996  139.759995  139.479996   5430500.0
# 2021-07-30  144.539993  141.550003  142.000000  142.229996  14393900.0
# 2021-08-02  142.429993  140.800003  141.770004  141.880005   7009500.0
# 2021-08-03  144.210007  141.520004  141.860001  143.949997   8455700.0
# 2021-08-04  144.089996  142.350006  143.039993  142.429993   6628000.0
# 2021-08-05  143.550003  141.470001  143.350006  142.500000   5363300.0
# ...

# %%
#To create a data set containing 5 columns representing adjusted closing prices of 5 different companies
#Procter&Gamble, Microsoft, AT&T, Ford, General Electrics
#Data : Adj Close

# %%
tickers = ['PG','MSFT','T','F','GE']
new_data = pd.DataFrame()  #empty dataframe

for i in tickers:
    new_data[i] = wb.DataReader( i, data_source = 'yahoo', start = '1995-1-1')['Adj Close']
new_data

#new_data['PG'] = wb.DataReader('PG', data_source='yahoo', start = '1995-1-1')['Adj Close']
#df['new'] = data['existing']
# Out:
#                     PG        MSFT          T          F          GE
# Date
# 1995-01-03    8.063840    2.383754   5.877185   4.380183   32.931717
# 1995-01-04    7.999201    2.401081   5.843583   4.498034   32.931717
# 1995-01-05    7.886079    2.361476   5.934889   4.458752   33.012394
# 1995-01-06    7.902242    2.401081   5.934889   4.458752   32.850979
# 1995-01-09    7.869921    2.386229   5.916626   4.537320   32.528118
# ...                ...         ...        ...        ...         ...
# 2021-08-11  142.619995  286.950012  28.160000  13.930000  106.040001
# 2021-08-12  142.949997  289.809998  28.020000  13.900000  106.519997
# 2021-08-13  143.639999  292.850006  28.190001  13.590000  104.919998
# 2021-08-16  144.639999  294.600006  28.200001  13.460000  103.349998
# 2021-08-17  144.880005  293.079987  28.190001  12.990000  101.620003
#
# [6704 rows x 5 columns]

# %%
new_data.tail()
# Out:
#                     PG        MSFT          T      F          GE
# Date
# 2021-08-11  142.619995  286.950012  28.160000  13.93  106.040001
# 2021-08-12  142.949997  289.809998  28.020000  13.90  106.519997
# 2021-08-13  143.639999  292.850006  28.190001  13.59  104.919998
# 2021-08-16  144.639999  294.600006  28.200001  13.46  103.349998
# 2021-08-17  144.880005  293.079987  28.190001  12.99  101.620003

# %%
#IEX does not provide data for more than 5 years prior to the data in which you execute the code

# %%
#pip3 install quandl
import quandl

# %%
mydata1 = quandl.get("FRED/GDP")

# %%
mydata1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6b6d8734bdac> in <module>
# ----> 1 mydata1.head()
#
# NameError: name 'mydata1' is not defined

# %%
#saving this data to csv file
import pandas as pd

# %%
#data-to-convert.to_csv('path/give-a-filename.csv')
PG.to_csv('C:/Aditi/My Work/Udemy/Finance Python/example1.csv')

# %%
#import a csv file
PG = pd.read_csv('C:/Aditi/My Work/Udemy/Finance Python/example1.csv')
PG.head()
# Out:
#          Date      High       Low      Open     Close     Volume  Adj Close
# 0  1995-01-03  15.62500  15.43750  15.46875  15.59375  3318400.0   8.063840
# 1  1995-01-04  15.65625  15.31250  15.53125  15.46875  2218800.0   7.999201
# 2  1995-01-05  15.43750  15.21875  15.37500  15.25000  2319600.0   7.886079
# 3  1995-01-06  15.40625  15.15625  15.15625  15.28125  3438000.0   7.902242
# 4  1995-01-09  15.40625  15.18750  15.34375  15.21875  1795200.0   7.869921

# %%
#exporting data as an excel file
#data-to-convert.to_excel('path/give-a-name.xlsx')
PG.to_excel('C:/Aditi/My Work/Udemy/Finance Python/example2.xlsx')

# %% [markdown]
# # Changing the Index of your Time-Series Data

# %%
mydata2 = pd.read_csv('C:/Aditi/My Work/Udemy/Finance Python/Data_02.csv')

# %%
mydata2
# Out:
#             Date    Open      High     Low     Close       Volume  \
# 0     2017-03-03  136.63  137.3300  136.08  137.1300   11095605.0
# 1     2017-03-02  137.09  137.8200  136.31  136.7603   12243028.0
# 2     2017-03-01  136.47  137.4800  136.30  137.4200   16257010.0
# 3     2017-02-28  136.79  136.8050  134.75  135.5400   16112092.0
# 4     2017-02-27  135.26  137.1846  135.02  136.4100   14306668.0
# ...          ...     ...       ...     ...       ...          ...
# 1200  2012-05-24   32.95   33.2100   31.77   33.0300   50237200.0
# 1201  2012-05-23   31.37   32.5000   31.36   32.0000   73600000.0
# 1202  2012-05-22   32.61   33.5900   30.94   31.0000  101786600.0
# 1203  2012-05-21   36.53   36.6600   33.00   34.0300  168192700.0
# 1204  2012-05-18   42.05   45.0000   38.00   38.2318  573576400.0
#
#       Ex-Dividend  Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# 0             0.0          1.0     136.63   137.3300    136.08    137.1300
# ...

# %%
#To set dates as the index
mydata2 = pd.read_csv('C:/Aditi/My Work/Udemy/Finance Python/Data_02.csv', index_col='Date')

# %%
mydata2
# Out:
#               Open      High     Low     Close       Volume  Ex-Dividend  \
# Date
# 2017-03-03  136.63  137.3300  136.08  137.1300   11095605.0          0.0
# 2017-03-02  137.09  137.8200  136.31  136.7603   12243028.0          0.0
# 2017-03-01  136.47  137.4800  136.30  137.4200   16257010.0          0.0
# 2017-02-28  136.79  136.8050  134.75  135.5400   16112092.0          0.0
# 2017-02-27  135.26  137.1846  135.02  136.4100   14306668.0          0.0
# ...            ...       ...     ...       ...          ...          ...
# 2012-05-24   32.95   33.2100   31.77   33.0300   50237200.0          0.0
# 2012-05-23   31.37   32.5000   31.36   32.0000   73600000.0          0.0
# 2012-05-22   32.61   33.5900   30.94   31.0000  101786600.0          0.0
# 2012-05-21   36.53   36.6600   33.00   34.0300  168192700.0          0.0
# 2012-05-18   42.05   45.0000   38.00   38.2318  573576400.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High  Adj. Low  Adj. Close  \
# Date
